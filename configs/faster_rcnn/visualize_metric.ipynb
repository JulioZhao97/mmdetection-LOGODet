# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)
print(len(base_logs))

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps)
# Out:
# ['20210321_222244.log', '20210321_224629.log', '20210321_231047.log', '20210321_233518.log', '20210321_235958.log', '20210322_002518.log', '20210322_004949.log', '20210322_011424.log', '20210322_013845.log', '20210322_020321.log', '20210325_224838.log', '20210325_231150.log', '20210325_233506.log', '20210325_235815.log', '20210326_002125.log', '20210326_004440.log', '20210326_010802.log', '20210326_013121.log', '20210326_015440.log', '20210326_021750.log', '20210326_024105.log', '20210326_030410.log', '20210326_032720.log', '20210326_035033.log', '20210326_041340.log', '20210326_043657.log', '20210326_050008.log', '20210326_052311.log', '20210326_054616.log', '20210326_060930.log', '20210326_063255.log', '20210326_065607.log', '20210326_071933.log', '20210326_074308.log', '20210326_080612.log', '20210326_082916.log', '20210326_085219.log', '20210326_091532.log', '20210326_093843.log', '20210326_100151.log']
# 40

# %%
plt.figure(figsize=(30, 10))

mean_ap = 0

for maps in maps_all_base:
    begin, step = 200, 200
    x = list(range(begin, begin + step * len(maps), 200))
    max_map, max_index = max(maps), maps.index(max(maps))
    mean_ap += max_map
    print(max_map, max_index)
    plt.plot(x, maps)
    plt.text(x[max_index], max_map, round(max_map, 3), ha='center', va='bottom', fontsize=10)
mean_ap /= len(base_logs)
print(mean_ap)
# Out:
# 0.5694522857666016 31
# 0.5793612599372864 6
# 0.5300577282905579 24
# 0.49724841117858887 6
# 0.5389489531517029 22
# 0.604404866695404 17
# 0.6038939356803894 17
# 0.44901546835899353 22
# 0.5593723654747009 31
# 0.5401055216789246 14
# 0.4981038570404053 31
# 0.514596700668335 22
# 0.5223594307899475 31
# 0.49388232827186584 20
# 0.44393205642700195 17
# 0.4766884744167328 22
# 0.4713118076324463 24
# 0.5223939418792725 17
# 0.5000938773155212 17
# 0.5816733837127686 20
# 0.5822969079017639 24
# 0.5182104706764221 17
# 0.5414366126060486 24
# 0.5271144509315491 31
# 0.5112448334693909 32
# 0.6143924593925476 6
# 0.5574595332145691 22
# 0.6047534942626953 17
# 0.5041974782943726 17
# 0.5185660719871521 22
# 0.5639762878417969 22
# 0.5189154148101807 22
# 0.5570566058158875 6
# 0.5145884156227112 5
# 0.5058572888374329 6
# 0.5321630835533142 24
# 0.5149135589599609 6
# 0.6168845295906067 6
# 0.48564091324806213 17
# 0.6063924431800842 17
# 0.5348239377140999

# %%
# visualize support pictures
from matplotlib import pyplot as plt
from PIL import Image
import os

imgs = ['000565.jpg', '054646.jpg', '058428.jpg']
for img in imgs:
    pic = Image.open(os.path.join('/data/zhaozhiyuan/tb_variation/VOCdevkit_all/VOC2007/', 'JPEGImages', img))
    plt.imshow(pic)
    plt.show()

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps)
# Out:
# ['20210325_121459.log', '20210325_131710.log', '20210325_141927.log', '20210325_152142.log', '20210325_162334.log', '20210325_172519.log', '20210325_182658.log', '20210325_192921.log', '20210325_203141.log', '20210325_213327.log', '20210326_100459.log', '20210326_152323.log', '20210326_162449.log', '20210326_172656.log', '20210326_182853.log', '20210326_193026.log', '20210326_203210.log', '20210326_213404.log', '20210326_223531.log', '20210326_233707.log', '20210327_003907.log']

# %%
plt.figure(figsize=(30, 10))

mean_ap = 0

for maps in maps_all_base:
    begin, step = 200, 200
    x = list(range(begin, begin + step * len(maps), step))
    max_map, max_index = max(maps), maps.index(max(maps))
    print(max_map, max_index)
    mean_ap += max_map
    plt.plot(x, maps)
    plt.text(x[max_index], max_map, round(max_map, 3), ha='center', va='bottom', fontsize=10)
mean_ap /= len(base_logs)
print(mean_ap)
# Out:
# 0.4224822521209717 22
# 0.5913242697715759 29
# 0.5471556186676025 29
# 0.4829352796077728 17
# 0.5291098952293396 31
# 0.5815906524658203 22
# 0.6359678506851196 17
# 0.4601786136627197 17
# 0.5408471822738647 17
# 0.4502390921115875 20
# 0.5182066559791565 17
# 0.516139566898346 17
# 0.6087183356285095 31
# 0.5230717062950134 17
# 0.6701068878173828 31
# 0.5000191926956177 17
# 0.5662223696708679 20
# 0.5858530402183533 22
# 0.669240415096283 31
# 0.5146236419677734 20
# 0.5248146057128906 22
# 0.5447070059322175

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_pr'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps)
# Out:
# ['20210325_121814.log', '20210325_134949.log', '20210325_152103.log', '20210325_165222.log', '20210325_182357.log', '20210325_195601.log', '20210325_212741.log', '20210325_225917.log', '20210326_003101.log', '20210326_020231.log', '20210326_152437.log', '20210326_165645.log', '20210326_182831.log', '20210326_200026.log', '20210326_213207.log', '20210326_230414.log', '20210327_003621.log', '20210327_020755.log', '20210327_034017.log', '20210327_051234.log']

# %%
plt.figure(figsize=(30, 10))

mean_ap = 0

for maps in maps_all_base:
    begin, step = 200, 200
    x = list(range(begin, begin + step * len(maps), step))
    max_map, max_index = max(maps), maps.index(max(maps))
    print(max_map, max_index)
    mean_ap += max_map
    plt.plot(x, maps)
    plt.text(x[max_index], max_map, round(max_map, 3), ha='center', va='bottom', fontsize=10)
mean_ap /= len(base_logs)
print(mean_ap)
# Out:
# 0.4930990934371948 31
# 0.49077939987182617 20
# 0.5557451844215393 17
# 0.5415933728218079 37
# 0.5423564314842224 17
# 0.5305889844894409 17
# 0.5452167391777039 17
# 0.5325106978416443 31
# 0.5989285707473755 22
# 0.5817831754684448 22
# 0.46852612495422363 18
# 0.5598061680793762 22
# 0.5532190799713135 17
# 0.5069019198417664 22
# 0.49421700835227966 17
# 0.5706869959831238 17
# 0.5363280177116394 17
# 0.49753880500793457 22
# 0.5458051562309265 9
# 0.5929320454597473 22
# 0.5369281485676766

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_fixed'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps)
# Out:
# ['20210327_231123.log', '20210328_004042.log', '20210328_021023.log', '20210328_033957.log', '20210328_050936.log', '20210328_063827.log', '20210328_080732.log', '20210328_093638.log', '20210328_110517.log', '20210328_123407.log']

# %%
plt.figure(figsize=(30, 10))

mean_ap = 0

for maps in maps_all_base:
    begin, step = 200, 200
    x = list(range(begin, begin + step * len(maps), step))
    max_map, max_index = max(maps), maps.index(max(maps))
    print(max_map, max_index)
    mean_ap += max_map
    plt.plot(x, maps)
    plt.text(x[max_index], max_map, round(max_map, 3), ha='center', va='bottom', fontsize=10)
mean_ap /= len(base_logs)
print(mean_ap)
# Out:
# 0.5573034286499023 20
# 0.5341995358467102 35
# 0.595005452632904 31
# 0.6130301356315613 22
# 0.4419543743133545 20
# 0.5536521077156067 38
# 0.5072636604309082 20
# 0.4212951362133026 11
# 0.6075324416160583 31
# 0.6367464661598206 31
# 0.5467982739210129

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_sample3000'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps)
# Out:
# ['20210329_160239.log', '20210329_190740.log', '20210329_221053.log', '20210330_011555.log', '20210330_041908.log']

# %%
plt.figure(figsize=(30, 10))

mean_ap = 0

for maps in maps_all_base:
    begin, step = 1000, 1000
    x = list(range(begin, begin + step * len(maps), step))
    max_map, max_index = max(maps), maps.index(max(maps))
    print(max_map, max_index)
    mean_ap += max_map
    plt.plot(x, maps)
    plt.text(x[max_index], max_map, round(max_map, 3), ha='center', va='bottom', fontsize=10)
mean_ap /= len(base_logs)
print(mean_ap)
# Out:
# 0.48898327350616455 2
# 0.4163472652435303 4
# 0.5204195380210876 1
# 0.49701276421546936 7
# 0.4991122782230377 3
# 0.48437502384185793

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_sample3000'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps)
# Out:
# ['20210329_144857.log', '20210329_155451.log', '20210329_170100.log', '20210329_180655.log', '20210329_194409.log']

# %%
plt.figure(figsize=(30, 10))

mean_ap = 0

for maps in maps_all_base:
    begin, step = 1000, 1000
    x = list(range(begin, begin + step * len(maps), step))
    max_map, max_index = max(maps), maps.index(max(maps))
    print(max_map, max_index)
    mean_ap += max_map
    plt.plot(x, maps)
    plt.text(x[max_index], max_map, round(max_map, 3), ha='center', va='bottom', fontsize=10)
mean_ap /= len(base_logs)
print(mean_ap)
# Out:
# 0.4506107568740845 1
# 0.4923888146877289 1
# 0.43180814385414124 5
# 0.4568333327770233 1
# 0.3951070010662079 1
# 0.44534960985183714

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_ca_3classes_sample3000'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps)
# Out:
# ['20210329_151719.log', '20210329_182823.log', '20210329_213908.log', '20210330_005005.log', '20210330_040113.log']

# %%
plt.figure(figsize=(30, 10))

mean_ap = 0

for maps in maps_all_base:
    begin, step = 1000, 1000
    x = list(range(begin, begin + step * len(maps), step))
    max_map, max_index = max(maps), maps.index(max(maps))
    print(max_map, max_index)
    mean_ap += max_map
    plt.plot(x, maps)
    plt.text(x[max_index], max_map, round(max_map, 3), ha='center', va='bottom', fontsize=10)
mean_ap /= len(base_logs)
print(mean_ap)
# Out:
# 0.19408106803894043 6
# 0.4029702842235565 6
# 0.4210222661495209 2
# 0.3570001423358917 1
# 0.4149819314479828 2
# 0.3580111384391785

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_3_31'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps[0])
print(maps_all_base)
print(sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210331_081705.log', '20210331_091447.log', '20210331_101244.log', '20210331_111024.log', '20210331_120824.log', '20210331_130558.log', '20210331_140357.log', '20210331_150250.log', '20210331_160052.log', '20210331_165852.log']
# [0.3130393922328949, 0.3975566625595093, 0.3711303174495697, 0.38567283749580383, 0.3883928060531616, 0.37471821904182434, 0.3969838619232178, 0.35663387179374695, 0.23482835292816162, 0.25940027832984924]
# 0.3478356599807739

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_3_31'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps[0])
print(maps_all_base)
print(sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210331_081746.log', '20210331_105246.log', '20210331_132805.log', '20210331_160254.log', '20210331_183912.log', '20210331_211446.log', '20210331_235011.log', '20210401_022532.log', '20210401_050118.log', '20210401_073623.log']
# [0.3625987470149994, 0.43430230021476746, 0.3912925720214844, 0.39980843663215637, 0.45215925574302673, 0.3867902457714081, 0.4446272552013397, 0.4290558397769928, 0.41580677032470703, 0.3040526807308197]
# 0.40204941034317015

# %%
import os
from matplotlib import pyplot as plt

logs_path = '/data/zhaozhiyuan/mmdetection_checkpoints/4_4/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes'
base_logs = [f for f in os.listdir(logs_path) if '.log' in f and 'json' not in f]
print(base_logs)

maps_all_base = []
for log in base_logs:
    f = open(os.path.join(logs_path, log), 'r')
    lines = f.readlines()
    lines = [line for line in lines if 'mAP' in line]
    maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
    maps_all_base.append(maps[0])
print(maps_all_base)
print(sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210404_000542.log', '20210404_032340.log', '20210404_064208.log', '20210404_095900.log', '20210404_131631.log']
# [0.3601410686969757, 0.39992937445640564, 0.26179468631744385, 0.3751932680606842, 0.4232591688632965]
# 0.3640635132789612

# %% [markdown]
# baseline module

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_4/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_test_param',
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_6/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_test_param'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
        maps_all_base.append(maps[0])
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210404_000448.log', '20210404_011711.log', '20210404_022905.log', '20210404_034324.log', '20210404_045703.log']
# ['20210405_141527.log', '20210405_152811.log', '20210405_163955.log', '20210405_175142.log', '20210405_190338.log', '20210405_201540.log', '20210405_212802.log', '20210405_224013.log', '20210405_235217.log', '20210406_010441.log', '20210406_102110.log', '20210406_113441.log', '20210406_124701.log', '20210406_135922.log', '20210406_151615.log']
# 20
# max: 0.34136125445365906
# min: 0.21658240258693695
# avg: 0.27734949216246607

# %% [markdown]
# out method

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_4/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_idea_test',
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_6/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_idea_test'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
        maps_all_base.append(maps[0])
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210404_192031.log', '20210404_230457.log', '20210405_024903.log', '20210405_063305.log', '20210405_101657.log']
# ['20210405_233729.log', '20210406_032141.log', '20210406_070517.log', '20210406_104940.log', '20210406_143452.log']
# 10
# max: 0.46500393748283386
# min: 0.3461371660232544
# avg: 0.41895350217819216

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_12/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_idea_test_softmax',
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
        maps_all_base.append(maps[0])
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210412_100250.log', '20210412_134445.log', '20210412_172729.log', '20210412_211355.log', '20210413_005929.log']
# 5
# max: 0.43155479431152344
# min: 0.35049232840538025
# avg: 0.3935972034931183

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_9/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_idea_test'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
        maps_all_base.append(maps[0])
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210410_170656.log', '20210410_204321.log', '20210411_002557.log', '20210411_040839.log', '20210411_075137.log']
# 5
# max: 0.3480563163757324
# min: 0.0
# avg: 0.22903574705123902

# %% [markdown]
# 测试训练中的波动

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_7/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_test_param_multi_step_40000epoch'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
        maps_all_base.append(maps[0])
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210407_094617.log', '20210407_120700.log', '20210407_142639.log', '20210407_164803.log', '20210407_190851.log']
# 5
# max: 0.337986022233963
# min: 0.20434649288654327
# avg: 0.26522276997566224

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_8/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_test_param_multi_step_30000epoch'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = [float(line.split(':')[-1].split('}')[0].split(' ')[-1]) for line in lines]
        maps_all_base.append(maps[0])
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210407_222704.log', '20210408_015406.log', '20210408_052429.log', '20210408_085420.log', '20210408_120802.log', '20210409_083730.log', '20210409_103010.log', '20210409_122409.log', '20210409_141634.log', '20210409_161025.log']
# 10
# max: 0.31179314851760864
# min: 0.2036469727754593
# avg: 0.25147832483053206

# %% [markdown]
# <font size=10>测试初始化方法</font>

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_14/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_test_mmcv_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210414_231434.log', '20210415_002604.log', '20210415_013900.log', '20210415_025052.log', '20210415_040241.log']
# 5
# max: 0.3737996816635132
# min: 0.24395938217639923
# avg: 0.2884720593690872

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_14/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_test_torch_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210414_231559.log', '20210415_002747.log', '20210415_013946.log', '20210415_025109.log', '20210415_040238.log']
# 5
# max: 0.4030562937259674
# min: 0.3589003384113312
# avg: 0.3779649376869202

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_16/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_torch_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210416_114726.log', '20210416_150846.log', '20210416_182729.log', '20210416_214240.log', '20210417_005642.log', '20210417_041001.log']
# 6
# max: 0.5405094027519226
# min: 0.2724210321903229
# avg: 0.42817199726899463

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_17/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_uniform_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210417_082929.log', '20210417_104323.log', '20210417_130430.log', '20210417_151640.log', '20210417_174001.log']
# 5
# max: 0.30540645122528076
# min: 0.18829579651355743
# avg: 0.2496045410633087

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_14/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_normal_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210417_082756.log', '20210417_103954.log', '20210417_125937.log', '20210417_151326.log', '20210417_173522.log']
# 5
# max: 0.3583732843399048
# min: 0.28650400042533875
# avg: 0.31553630232810975

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_17/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_normal_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210417_083255.log', '20210417_114859.log', '20210417_150512.log', '20210417_182200.log', '20210417_214251.log']
# 5
# max: 0.4628537595272064
# min: 0.32743141055107117
# avg: 0.36006263494491575

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_18/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_idea_test'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210418_090117.log', '20210418_124535.log', '20210418_163111.log', '20210418_201615.log', '20210419_000212.log']
# 5
# max: 0.518474280834198
# min: 0.40437600016593933
# avg: 0.44389713406562803

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_19/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_idea_test'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210420_001112.log', '20210420_035343.log', '20210420_073538.log', '20210420_111759.log', '20210420_150034.log']
# 5
# max: 0.5147927403450012
# min: 0.3940257132053375
# avg: 0.4427332401275635

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_19/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210419_201812.log', '20210419_233023.log', '20210420_024217.log', '20210420_055310.log', '20210420_090357.log']
# 5
# max: 0.41878771781921387
# min: 0.2509016990661621
# avg: 0.3061064064502716

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_21/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_normal_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210421_004205.log', '20210421_015357.log', '20210421_030621.log', '20210421_041933.log', '20210421_053219.log']
# 5
# max: 0.39301490783691406
# min: 0.2434861660003662
# avg: 0.31415600776672364

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_22/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_normal_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210422_104329.log', '20210422_104340.log', '20210422_104344.log', '20210422_104348.log', '20210422_104351.log', '20210422_135542.log', '20210422_135553.log', '20210422_135713.log', '20210422_135918.log', '20210422_140400.log']
# 10
# max: 0.48191842436790466
# min: 0.2547287046909332
# avg: 0.3592942953109741

# %% [markdown]
# 4月23日实验

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_23/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_idea_test'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210423_093119.log', '20210423_093125.log', '20210423_093129.log', '20210423_093132.log', '20210423_093137.log', '20210423_131359.log', '20210423_131647.log', '20210423_131737.log', '20210423_131742.log', '20210423_131743.log']
# 10
# max: 0.5280473232269287
# min: 0.3171516954898834
# avg: 0.4422854512929916

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_23/logo_faster_rcnn_r50_fpn_1x_coco_attention_detector_3classes_normal_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210423_172602.log', '20210423_172611.log', '20210423_172623.log', '20210423_172630.log', '20210423_172643.log', '20210423_203952.log', '20210423_203957.log', '20210423_204015.log', '20210423_204244.log', '20210423_204305.log']
# 10
# max: 0.44639334082603455
# min: 0.2889654338359833
# avg: 0.3514334291219711

# %%
import os
from matplotlib import pyplot as plt

logs_path = [
    '/data/zhaozhiyuan/mmdetection_checkpoints/4_23/logo_faster_rcnn_r50_fpn_1x_coco_base_3classes_normal_init'
]

maps_all_base = []

for log_path in logs_path:
    base_logs = [f for f in os.listdir(log_path) if '.log' in f and 'json' not in f]
    print(base_logs)

    for log in base_logs:
        f = open(os.path.join(log_path, log), 'r')
        lines = f.readlines()
        lines = [line for line in lines if 'mAP' in line]
        maps = float(lines[-1].split(':')[-1].split('}')[0].split(' ')[-1])
        maps_all_base.append(maps)
print(len(maps_all_base))
print('max:',max(maps_all_base))
print('min:',min(maps_all_base))
print('avg:',sum(maps_all_base) / len(maps_all_base))
# Out:
# ['20210424_001311.log', '20210424_001315.log', '20210424_012641.log', '20210424_012734.log', '20210424_024017.log', '20210424_024124.log', '20210424_035429.log', '20210424_035456.log', '20210424_050813.log', '20210424_050859.log']
# 10
# max: 0.38474002480506897
# min: 0.2641192376613617
# avg: 0.3080528676509857
